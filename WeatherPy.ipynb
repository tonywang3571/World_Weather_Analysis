# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create sets of random latitudes and longitudes.
lats = np.random.uniform(low=-90, high=90, size=1500)
lngs = np.random.uniform(low=-90, high=90, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holidng cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for i in coordinates:
    city = citipy.nearest_city(i[0], i[1]).city_name
    
    # IF city is unique, add to list.
    if city not in cities:
        cities.append(city)
# Print city count to confirm sufficient count.
len(cities)
# Out:
# 612

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an endpoint URL for a city.
#city_url = url + "&q=" + "city"

# %%
# import the time library and the datetime module from the dattime library
import time
from datetime import datetime

# %%
# declare empty list
city_data = []
# print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# loop through all the cities in the list.
# enumerate iterates through list of citiies and retrieves both the index and city name from the list
for i, city in enumerate(cities):
    
    # Group citiies in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | pisco
# Processing Record 2 of Set 1 | chuy
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | arraial do cabo
# Processing Record 6 of Set 1 | coquimbo
# Processing Record 7 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 1 | rincon
# Processing Record 9 of Set 1 | rawson
# Processing Record 10 of Set 1 | dikson
# Processing Record 11 of Set 1 | baherden
# Processing Record 12 of Set 1 | port alfred
# Processing Record 13 of Set 1 | botwood
# Processing Record 14 of Set 1 | dmitriyevka
# Processing Record 15 of Set 1 | sao filipe
# Processing Record 16 of Set 1 | puerto del rosario
# Processing Record 17 of Set 1 | presidencia roque saenz pena
# Processing Record 18 of Set 1 | santa fe
# Processing Record 19 of Set 1 | adre
# Processing Record 20 of Set 1 | saint-felicien
# Processing Record 21 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 1 | dwarka
# Processing Record 23 of Set 1 | rudnichnyy
# Processing Record 24 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | namibe
# Processing Record 28 of Set 1 | lagoa
# Processing Record 29 of Set 1 | marawi
# Processing Record 30 of Set 1 | hambantota
# Processing Record 31 of Set 1 | jamestown
# Processing Record 32 of Set 1 | caravelas
# Processing Record 33 of Set 1 | hithadhoo
# Processing Record 34 of Set 1 | saint george
# Processing Record 35 of Set 1 | monzon
# Processing Record 36 of Set 1 | saint-philippe
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | alto araguaia
# Processing Record 39 of Set 1 | naftah
# City not found. Skipping...
# Processing Record 40 of Set 1 | touros
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | manyana
# Processing Record 43 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 1 | navabad
# City not found. Skipping...
# Processing Record 45 of Set 1 | saint anthony
# Processing Record 46 of Set 1 | vieste
# Processing Record 47 of Set 1 | east london
# Processing Record 48 of Set 1 | bredasdorp
# Processing Record 49 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 50 of Set 1 | bathsheba
# Processing Record 1 of Set 2 | puerto carreno
# Processing Record 2 of Set 2 | vila velha
# Processing Record 3 of Set 2 | suluq
# Processing Record 4 of Set 2 | mahebourg
# Processing Record 5 of Set 2 | hermanus
# Processing Record 6 of Set 2 | maxixe
# Processing Record 7 of Set 2 | coihaique
# Processing Record 8 of Set 2 | ngaoundere
# Processing Record 9 of Set 2 | tessalit
# Processing Record 10 of Set 2 | zwedru
# Processing Record 11 of Set 2 | zmeinogorsk
# Processing Record 12 of Set 2 | acarau
# Processing Record 13 of Set 2 | san jose de guanipa
# Processing Record 14 of Set 2 | qaanaaq
# Processing Record 15 of Set 2 | olmos
# Processing Record 16 of Set 2 | khandbari
# Processing Record 17 of Set 2 | nyagan
# Processing Record 18 of Set 2 | georgetown
# Processing Record 19 of Set 2 | hoopstad
# Processing Record 20 of Set 2 | clyde river
# Processing Record 21 of Set 2 | juan lacaze
# Processing Record 22 of Set 2 | longyearbyen
# Processing Record 23 of Set 2 | polyarnyy
# Processing Record 24 of Set 2 | bambous virieux
# Processing Record 25 of Set 2 | chinhoyi
# Processing Record 26 of Set 2 | jacareacanga
# Processing Record 27 of Set 2 | tasiilaq
# Processing Record 28 of Set 2 | maues
# Processing Record 29 of Set 2 | galdar
# Processing Record 30 of Set 2 | dingle
# Processing Record 31 of Set 2 | mar del plata
# Processing Record 32 of Set 2 | narsaq
# Processing Record 33 of Set 2 | linares
# Processing Record 34 of Set 2 | riyadh
# Processing Record 35 of Set 2 | nantucket
# Processing Record 36 of Set 2 | meulaboh
# Processing Record 37 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 2 | cockburn town
# Processing Record 39 of Set 2 | klaksvik
# Processing Record 40 of Set 2 | upernavik
# Processing Record 41 of Set 2 | qasigiannguit
# Processing Record 42 of Set 2 | umm durman
# City not found. Skipping...
# Processing Record 43 of Set 2 | patos de minas
# Processing Record 44 of Set 2 | ilulissat
# Processing Record 45 of Set 2 | ribeira grande
# Processing Record 46 of Set 2 | do rud
# City not found. Skipping...
# Processing Record 47 of Set 2 | san ramon
# Processing Record 48 of Set 2 | gazanjyk
# Processing Record 49 of Set 2 | williamsburg
# Processing Record 50 of Set 2 | carnarvon
# Processing Record 1 of Set 3 | skalistyy
# City not found. Skipping...
# Processing Record 2 of Set 3 | khowst
# Processing Record 3 of Set 3 | thunder bay
# Processing Record 4 of Set 3 | havre-saint-pierre
# Processing Record 5 of Set 3 | ponta do sol
# Processing Record 6 of Set 3 | novyy urengoy
# Processing Record 7 of Set 3 | santo tomas
# Processing Record 8 of Set 3 | gazli
# Processing Record 9 of Set 3 | mastic beach
# Processing Record 10 of Set 3 | brandys nad labem-stara boleslav
# Processing Record 11 of Set 3 | beawar
# Processing Record 12 of Set 3 | sur
# Processing Record 13 of Set 3 | ponta delgada
# Processing Record 14 of Set 3 | jinka
# Processing Record 15 of Set 3 | moose factory
# Processing Record 16 of Set 3 | guelengdeng
# City not found. Skipping...
# Processing Record 17 of Set 3 | san cristobal
# Processing Record 18 of Set 3 | ngozi
# Processing Record 19 of Set 3 | kuytun
# Processing Record 20 of Set 3 | port elizabeth
# Processing Record 21 of Set 3 | sakakah
# Processing Record 22 of Set 3 | cordoba
# Processing Record 23 of Set 3 | cabedelo
# Processing Record 24 of Set 3 | bilma
# Processing Record 25 of Set 3 | cayenne
# Processing Record 26 of Set 3 | kirovsk
# Processing Record 27 of Set 3 | baghdad
# Processing Record 28 of Set 3 | souillac
# Processing Record 29 of Set 3 | omboue
# Processing Record 30 of Set 3 | saldanha
# Processing Record 31 of Set 3 | saint-augustin
# Processing Record 32 of Set 3 | teruel
# Processing Record 33 of Set 3 | luderitz
# Processing Record 34 of Set 3 | balkhash
# Processing Record 35 of Set 3 | teguise
# Processing Record 36 of Set 3 | puerto ayacucho
# Processing Record 37 of Set 3 | ahwa
# Processing Record 38 of Set 3 | sorland
# Processing Record 39 of Set 3 | kasongo-lunda
# Processing Record 40 of Set 3 | blankenberge
# Processing Record 41 of Set 3 | viedma
# Processing Record 42 of Set 3 | koungou
# Processing Record 43 of Set 3 | nakuru
# Processing Record 44 of Set 3 | bandarbeyla
# Processing Record 45 of Set 3 | kruisfontein
# Processing Record 46 of Set 3 | itarema
# Processing Record 47 of Set 3 | iqaluit
# Processing Record 48 of Set 3 | chapais
# Processing Record 49 of Set 3 | barrancas
# Processing Record 50 of Set 3 | obera
# Processing Record 1 of Set 4 | mangrol
# Processing Record 2 of Set 4 | hamilton
# Processing Record 3 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 4 | gornopravdinsk
# Processing Record 5 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 6 of Set 4 | saint-pierre
# Processing Record 7 of Set 4 | khor
# Processing Record 8 of Set 4 | grand gaube
# Processing Record 9 of Set 4 | methoni
# Processing Record 10 of Set 4 | adrar
# Processing Record 11 of Set 4 | ostrovnoy
# Processing Record 12 of Set 4 | ardesen
# Processing Record 13 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 4 | altonia
# City not found. Skipping...
# Processing Record 15 of Set 4 | cayambe
# Processing Record 16 of Set 4 | plettenberg bay
# Processing Record 17 of Set 4 | pangody
# Processing Record 18 of Set 4 | portree
# Processing Record 19 of Set 4 | mehamn
# Processing Record 20 of Set 4 | arkhipo-osipovka
# Processing Record 21 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 22 of Set 4 | mbanza-ngungu
# Processing Record 23 of Set 4 | boffa
# Processing Record 24 of Set 4 | salalah
# Processing Record 25 of Set 4 | ubrique
# Processing Record 26 of Set 4 | nanortalik
# Processing Record 27 of Set 4 | halver
# Processing Record 28 of Set 4 | batsfjord
# Processing Record 29 of Set 4 | melhus
# Processing Record 30 of Set 4 | kavaratti
# Processing Record 31 of Set 4 | mahibadhoo
# Processing Record 32 of Set 4 | nouadhibou
# Processing Record 33 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 4 | puerto baquerizo moreno
# Processing Record 35 of Set 4 | biharamulo
# Processing Record 36 of Set 4 | basoda
# Processing Record 37 of Set 4 | grindavik
# Processing Record 38 of Set 4 | zdvinsk
# Processing Record 39 of Set 4 | miandoab
# Processing Record 40 of Set 4 | la rioja
# Processing Record 41 of Set 4 | shu
# Processing Record 42 of Set 4 | san ramon de la nueva oran
# Processing Record 43 of Set 4 | morant bay
# Processing Record 44 of Set 4 | lere
# Processing Record 45 of Set 4 | bardiyah
# Processing Record 46 of Set 4 | yar-sale
# Processing Record 47 of Set 4 | oistins
# Processing Record 48 of Set 4 | kapoeta
# Processing Record 49 of Set 4 | naro
# Processing Record 50 of Set 4 | los llanos de aridane
# Processing Record 1 of Set 5 | nara
# Processing Record 2 of Set 5 | tabasalu
# Processing Record 3 of Set 5 | veinticinco de mayo
# Processing Record 4 of Set 5 | zuya
# Processing Record 5 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 6 of Set 5 | batetskiy
# Processing Record 7 of Set 5 | kaltasy
# Processing Record 8 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 9 of Set 5 | garissa
# Processing Record 10 of Set 5 | walvis bay
# Processing Record 11 of Set 5 | satana
# Processing Record 12 of Set 5 | tortoli
# Processing Record 13 of Set 5 | druzhba
# Processing Record 14 of Set 5 | morton
# Processing Record 15 of Set 5 | kovylkino
# Processing Record 16 of Set 5 | grosse pointe park
# Processing Record 17 of Set 5 | havoysund
# Processing Record 18 of Set 5 | lasa
# Processing Record 19 of Set 5 | sao joao da barra
# Processing Record 20 of Set 5 | terme
# Processing Record 21 of Set 5 | masvingo
# Processing Record 22 of Set 5 | victoria
# Processing Record 23 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 5 | sokoni
# Processing Record 25 of Set 5 | bosobolo
# Processing Record 26 of Set 5 | torbay
# Processing Record 27 of Set 5 | mysliborz
# Processing Record 28 of Set 5 | carutapera
# Processing Record 29 of Set 5 | magui
# City not found. Skipping...
# Processing Record 30 of Set 5 | valparaiso
# Processing Record 31 of Set 5 | vestmanna
# Processing Record 32 of Set 5 | dakar
# Processing Record 33 of Set 5 | bengkulu
# Processing Record 34 of Set 5 | tias
# Processing Record 35 of Set 5 | berlevag
# Processing Record 36 of Set 5 | turbat
# Processing Record 37 of Set 5 | tapes
# Processing Record 38 of Set 5 | tobol
# Processing Record 39 of Set 5 | yenagoa
# Processing Record 40 of Set 5 | husavik
# Processing Record 41 of Set 5 | port-gentil
# Processing Record 42 of Set 5 | cidreira
# Processing Record 43 of Set 5 | inderborskiy
# City not found. Skipping...
# Processing Record 44 of Set 5 | matara
# Processing Record 45 of Set 5 | harper
# Processing Record 46 of Set 5 | barkly west
# Processing Record 47 of Set 5 | inirida
# Processing Record 48 of Set 5 | gijon
# Processing Record 49 of Set 5 | bad durkheim
# Processing Record 50 of Set 5 | ihiala
# Processing Record 1 of Set 6 | kalisz
# Processing Record 2 of Set 6 | nizwa
# Processing Record 3 of Set 6 | casablanca
# Processing Record 4 of Set 6 | robertsport
# Processing Record 5 of Set 6 | mandal
# Processing Record 6 of Set 6 | strathpeffer
# Processing Record 7 of Set 6 | taft
# Processing Record 8 of Set 6 | benghazi
# Processing Record 9 of Set 6 | saint-francois
# Processing Record 10 of Set 6 | razole
# Processing Record 11 of Set 6 | lyubashivka
# Processing Record 12 of Set 6 | camabatela
# Processing Record 13 of Set 6 | werota
# Processing Record 14 of Set 6 | san vicente
# Processing Record 15 of Set 6 | agadez
# Processing Record 16 of Set 6 | bonavista
# Processing Record 17 of Set 6 | sao francisco
# Processing Record 18 of Set 6 | taoudenni
# Processing Record 19 of Set 6 | snezhnogorsk
# Processing Record 20 of Set 6 | kristiansund
# Processing Record 21 of Set 6 | rio gallegos
# Processing Record 22 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 6 | motul
# Processing Record 24 of Set 6 | filadelfia
# Processing Record 25 of Set 6 | abalak
# Processing Record 26 of Set 6 | naugarzan
# City not found. Skipping...
# Processing Record 27 of Set 6 | gravdal
# Processing Record 28 of Set 6 | limon
# Processing Record 29 of Set 6 | cap malheureux
# Processing Record 30 of Set 6 | pustoshka
# Processing Record 31 of Set 6 | chambas
# Processing Record 32 of Set 6 | safwah
# City not found. Skipping...
# Processing Record 33 of Set 6 | burica
# City not found. Skipping...
# Processing Record 34 of Set 6 | axim
# Processing Record 35 of Set 6 | tobermory
# Processing Record 36 of Set 6 | burayevo
# Processing Record 37 of Set 6 | manicore
# Processing Record 38 of Set 6 | bonthe
# Processing Record 39 of Set 6 | somerset
# Processing Record 40 of Set 6 | venafro
# Processing Record 41 of Set 6 | shchelyayur
# City not found. Skipping...
# Processing Record 42 of Set 6 | oranjemund
# Processing Record 43 of Set 6 | noyabrsk
# Processing Record 44 of Set 6 | castro
# Processing Record 45 of Set 6 | sidi bin nur
# Processing Record 46 of Set 6 | port-cartier
# Processing Record 47 of Set 6 | pokhara
# Processing Record 48 of Set 6 | rio grande
# Processing Record 49 of Set 6 | korla
# Processing Record 50 of Set 6 | gidole
# Processing Record 1 of Set 7 | bantry
# Processing Record 2 of Set 7 | tame
# Processing Record 3 of Set 7 | samastipur
# Processing Record 4 of Set 7 | synya
# Processing Record 5 of Set 7 | quelimane
# Processing Record 6 of Set 7 | bandundu
# Processing Record 7 of Set 7 | buraydah
# Processing Record 8 of Set 7 | lisala
# Processing Record 9 of Set 7 | karoi
# Processing Record 10 of Set 7 | jalu
# Processing Record 11 of Set 7 | filingue
# Processing Record 12 of Set 7 | osorno
# Processing Record 13 of Set 7 | corinto
# Processing Record 14 of Set 7 | kalmunai
# Processing Record 15 of Set 7 | deh rawud
# City not found. Skipping...
# Processing Record 16 of Set 7 | sandwick
# Processing Record 17 of Set 7 | san andres
# Processing Record 18 of Set 7 | padang
# Processing Record 19 of Set 7 | pedra branca
# Processing Record 20 of Set 7 | port blair
# Processing Record 21 of Set 7 | kyzyl-suu
# Processing Record 22 of Set 7 | kutum
# Processing Record 23 of Set 7 | muros
# Processing Record 24 of Set 7 | pitimbu
# Processing Record 25 of Set 7 | tiznit
# Processing Record 26 of Set 7 | laguna
# Processing Record 27 of Set 7 | madinat sittah uktubar
# Processing Record 28 of Set 7 | sangueya
# Processing Record 29 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 30 of Set 7 | ovre ardal
# Processing Record 31 of Set 7 | alashtar
# City not found. Skipping...
# Processing Record 32 of Set 7 | saint-max
# Processing Record 33 of Set 7 | mitsamiouli
# Processing Record 34 of Set 7 | taloqan
# Processing Record 35 of Set 7 | aanekoski
# Processing Record 36 of Set 7 | antalaha
# Processing Record 37 of Set 7 | hollins
# Processing Record 38 of Set 7 | argentan
# Processing Record 39 of Set 7 | north myrtle beach
# Processing Record 40 of Set 7 | carballo
# Processing Record 41 of Set 7 | kuito
# Processing Record 42 of Set 7 | nador
# Processing Record 43 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 44 of Set 7 | kashira
# Processing Record 45 of Set 7 | rio de janeiro
# Processing Record 46 of Set 7 | the valley
# Processing Record 47 of Set 7 | hudiksvall
# Processing Record 48 of Set 7 | porbandar
# Processing Record 49 of Set 7 | lisakovsk
# Processing Record 50 of Set 7 | ratoath
# Processing Record 1 of Set 8 | faya
# Processing Record 2 of Set 8 | el reten
# Processing Record 3 of Set 8 | minyar
# Processing Record 4 of Set 8 | rocha
# Processing Record 5 of Set 8 | laje
# Processing Record 6 of Set 8 | irbil
# Processing Record 7 of Set 8 | state college
# Processing Record 8 of Set 8 | ceres
# Processing Record 9 of Set 8 | sumter
# Processing Record 10 of Set 8 | thompson
# Processing Record 11 of Set 8 | beni mazar
# Processing Record 12 of Set 8 | teguldet
# Processing Record 13 of Set 8 | nortelandia
# Processing Record 14 of Set 8 | goderich
# Processing Record 15 of Set 8 | mogadishu
# Processing Record 16 of Set 8 | sumbe
# Processing Record 17 of Set 8 | pita
# Processing Record 18 of Set 8 | iranshahr
# Processing Record 19 of Set 8 | carikar
# City not found. Skipping...
# Processing Record 20 of Set 8 | santa luzia
# Processing Record 21 of Set 8 | tocopilla
# Processing Record 22 of Set 8 | kippen
# Processing Record 23 of Set 8 | salinopolis
# Processing Record 24 of Set 8 | santa cruz
# Processing Record 25 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 26 of Set 8 | kindu
# Processing Record 27 of Set 8 | la asuncion
# Processing Record 28 of Set 8 | maniitsoq
# Processing Record 29 of Set 8 | lebu
# Processing Record 30 of Set 8 | bartica
# Processing Record 31 of Set 8 | aswan
# Processing Record 32 of Set 8 | okahandja
# Processing Record 33 of Set 8 | darien
# Processing Record 34 of Set 8 | sanchor
# Processing Record 35 of Set 8 | humaita
# Processing Record 36 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 37 of Set 8 | ubinskoye
# Processing Record 38 of Set 8 | vestmannaeyjar
# Processing Record 39 of Set 8 | jacarezinho
# Processing Record 40 of Set 8 | kerki
# City not found. Skipping...
# Processing Record 41 of Set 8 | santa cruz de tenerife
# Processing Record 42 of Set 8 | ancud
# Processing Record 43 of Set 8 | middle island
# Processing Record 44 of Set 8 | beloha
# Processing Record 45 of Set 8 | avon
# Processing Record 46 of Set 8 | brae
# Processing Record 47 of Set 8 | aba
# Processing Record 48 of Set 8 | doha
# Processing Record 49 of Set 8 | albertville
# Processing Record 50 of Set 8 | hobyo
# Processing Record 1 of Set 9 | correntina
# Processing Record 2 of Set 9 | saint-medard-en-jalles
# Processing Record 3 of Set 9 | asfi
# Processing Record 4 of Set 9 | oranjestad
# Processing Record 5 of Set 9 | umm ruwabah
# City not found. Skipping...
# Processing Record 6 of Set 9 | deer lake
# Processing Record 7 of Set 9 | ariquemes
# Processing Record 8 of Set 9 | mutis
# Processing Record 9 of Set 9 | tiebissou
# Processing Record 10 of Set 9 | bako
# Processing Record 11 of Set 9 | bubaque
# Processing Record 12 of Set 9 | dunyapur
# Processing Record 13 of Set 9 | molepolole
# Processing Record 14 of Set 9 | tabuk
# Processing Record 15 of Set 9 | sosnovka
# Processing Record 16 of Set 9 | atar
# Processing Record 17 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 18 of Set 9 | shahpur
# Processing Record 19 of Set 9 | yabelo
# Processing Record 20 of Set 9 | brokopondo
# Processing Record 21 of Set 9 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 22 of Set 9 | huarmey
# Processing Record 23 of Set 9 | sande
# Processing Record 24 of Set 9 | marystown
# Processing Record 25 of Set 9 | okitipupa
# Processing Record 26 of Set 9 | saint andrews
# Processing Record 27 of Set 9 | luena
# Processing Record 28 of Set 9 | black river
# Processing Record 29 of Set 9 | esil
# Processing Record 30 of Set 9 | pangnirtung
# Processing Record 31 of Set 9 | yafran
# Processing Record 32 of Set 9 | garmsar
# Processing Record 33 of Set 9 | kayerkan
# Processing Record 34 of Set 9 | comodoro rivadavia
# Processing Record 35 of Set 9 | eseka
# Processing Record 36 of Set 9 | oksfjord
# Processing Record 37 of Set 9 | sangolqui
# Processing Record 38 of Set 9 | benjamin constant
# Processing Record 39 of Set 9 | pinega
# Processing Record 40 of Set 9 | paita
# Processing Record 41 of Set 9 | hilton head island
# Processing Record 42 of Set 9 | mao
# Processing Record 43 of Set 9 | trincomalee
# Processing Record 44 of Set 9 | turochak
# Processing Record 45 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 46 of Set 9 | ler
# Processing Record 47 of Set 9 | tabou
# Processing Record 48 of Set 9 | kuusamo
# Processing Record 49 of Set 9 | rafai
# Processing Record 50 of Set 9 | westport
# Processing Record 1 of Set 10 | arkhangelskoye
# Processing Record 2 of Set 10 | formosa do rio preto
# Processing Record 3 of Set 10 | les herbiers
# Processing Record 4 of Set 10 | strezhevoy
# Processing Record 5 of Set 10 | awbari
# Processing Record 6 of Set 10 | chipinge
# Processing Record 7 of Set 10 | lambarene
# Processing Record 8 of Set 10 | kargil
# Processing Record 9 of Set 10 | santa rosa
# Processing Record 10 of Set 10 | maracaju
# Processing Record 11 of Set 10 | calama
# Processing Record 12 of Set 10 | ierapetra
# Processing Record 13 of Set 10 | tazovskiy
# Processing Record 14 of Set 10 | sura mare
# Processing Record 15 of Set 10 | khuzdar
# Processing Record 16 of Set 10 | shahreza
# Processing Record 17 of Set 10 | khairagarh
# Processing Record 18 of Set 10 | konevo
# Processing Record 19 of Set 10 | ilhabela
# Processing Record 20 of Set 10 | acari
# Processing Record 21 of Set 10 | chipata
# Processing Record 22 of Set 10 | stykkisholmur
# Processing Record 23 of Set 10 | ribnitz-damgarten
# Processing Record 24 of Set 10 | ambilobe
# Processing Record 25 of Set 10 | olafsvik
# Processing Record 26 of Set 10 | liverpool
# Processing Record 27 of Set 10 | turayf
# Processing Record 28 of Set 10 | nardaran
# Processing Record 29 of Set 10 | chahal
# Processing Record 30 of Set 10 | kem
# Processing Record 31 of Set 10 | arlit
# Processing Record 32 of Set 10 | sompeta
# Processing Record 33 of Set 10 | kabinda
# Processing Record 34 of Set 10 | antalya
# Processing Record 35 of Set 10 | marsh harbour
# Processing Record 36 of Set 10 | sembe
# Processing Record 37 of Set 10 | sao felix do xingu
# Processing Record 38 of Set 10 | vila franca do campo
# Processing Record 39 of Set 10 | mahon
# Processing Record 40 of Set 10 | antsohihy
# Processing Record 41 of Set 10 | natitingou
# Processing Record 42 of Set 10 | birnin kebbi
# Processing Record 43 of Set 10 | saint-georges
# Processing Record 44 of Set 10 | polyarnyye zori
# Processing Record 45 of Set 10 | oranzherei
# Processing Record 46 of Set 10 | herend
# Processing Record 47 of Set 10 | kasumkent
# Processing Record 48 of Set 10 | high rock
# Processing Record 49 of Set 10 | penzance
# Processing Record 50 of Set 10 | pakala
# Processing Record 1 of Set 11 | szczytno
# Processing Record 2 of Set 11 | talara
# Processing Record 3 of Set 11 | itaituba
# Processing Record 4 of Set 11 | diu
# Processing Record 5 of Set 11 | elizabeth city
# Processing Record 6 of Set 11 | effium
# Processing Record 7 of Set 11 | barranca
# Processing Record 8 of Set 11 | road town
# Processing Record 9 of Set 11 | san antonio
# Processing Record 10 of Set 11 | harindanga
# Processing Record 11 of Set 11 | parintins
# Processing Record 12 of Set 11 | mitu
# Processing Record 13 of Set 11 | karasuk
# Processing Record 14 of Set 11 | ardistan
# City not found. Skipping...
# Processing Record 15 of Set 11 | gulshat
# City not found. Skipping...
# Processing Record 16 of Set 11 | cartagena
# Processing Record 17 of Set 11 | hofn
# Processing Record 18 of Set 11 | pauini
# Processing Record 19 of Set 11 | ambanja
# Processing Record 20 of Set 11 | luanda
# Processing Record 21 of Set 11 | savantvadi
# Processing Record 22 of Set 11 | igrim
# Processing Record 23 of Set 11 | karlskoga
# Processing Record 24 of Set 11 | macau
# Processing Record 25 of Set 11 | tanda
# Processing Record 26 of Set 11 | romanovka
# Processing Record 27 of Set 11 | cedar lake
# Processing Record 28 of Set 11 | aquiraz
# Processing Record 29 of Set 11 | mantua
# Processing Record 30 of Set 11 | unai
# Processing Record 31 of Set 11 | sinnamary
# Processing Record 32 of Set 11 | bela
# Processing Record 33 of Set 11 | pilna
# Processing Record 34 of Set 11 | mangan
# Processing Record 35 of Set 11 | matay
# Processing Record 36 of Set 11 | farah
# Processing Record 37 of Set 11 | araouane
# Processing Record 38 of Set 11 | krasnyy yar
# Processing Record 39 of Set 11 | alberton
# Processing Record 40 of Set 11 | hearst
# Processing Record 41 of Set 11 | mecca
# Processing Record 42 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 43 of Set 11 | ystad
# Processing Record 44 of Set 11 | leczyca
# Processing Record 45 of Set 11 | santiago
# Processing Record 46 of Set 11 | yarada
# Processing Record 47 of Set 11 | krutikha
# Processing Record 48 of Set 11 | maamba
# Processing Record 49 of Set 11 | mul
# Processing Record 50 of Set 11 | punghina
# Processing Record 1 of Set 12 | vilhena
# Processing Record 2 of Set 12 | iralaya
# Processing Record 3 of Set 12 | ouadda
# Processing Record 4 of Set 12 | leh
# Processing Record 5 of Set 12 | esna
# Processing Record 6 of Set 12 | iquique
# Processing Record 7 of Set 12 | bonfim
# Processing Record 8 of Set 12 | bodden town
# Processing Record 9 of Set 12 | richards bay
# Processing Record 10 of Set 12 | san francisco
# Processing Record 11 of Set 12 | kamina
# Processing Record 12 of Set 12 | mongu
# Processing Record 13 of Set 12 | dinsor
# City not found. Skipping...
# Processing Record 14 of Set 12 | shcholkine
# City not found. Skipping...
# Processing Record 15 of Set 12 | uusikaupunki
# Processing Record 16 of Set 12 | tromso
# Processing Record 17 of Set 12 | kangaatsiaq
# Processing Record 18 of Set 12 | matagami
# Processing Record 19 of Set 12 | le port
# Processing Record 20 of Set 12 | gat
# Processing Record 21 of Set 12 | puerto maldonado
# Processing Record 22 of Set 12 | palora
# Processing Record 23 of Set 12 | leshukonskoye
# Processing Record 24 of Set 12 | vardo
# Processing Record 25 of Set 12 | nieuw amsterdam
# Processing Record 26 of Set 12 | soria
# Processing Record 27 of Set 12 | aktau
# Processing Record 28 of Set 12 | akdepe
# Processing Record 29 of Set 12 | vikulovo
# Processing Record 30 of Set 12 | vacha
# Processing Record 31 of Set 12 | birjand
# Processing Record 32 of Set 12 | villa bruzual
# Processing Record 33 of Set 12 | marrakesh
# Processing Record 34 of Set 12 | honningsvag
# Processing Record 35 of Set 12 | steinkjer
# Processing Record 36 of Set 12 | altayskoye
# Processing Record 37 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 38 of Set 12 | douentza
# Processing Record 39 of Set 12 | urengoy
# Processing Record 40 of Set 12 | jabinyanah
# Processing Record 41 of Set 12 | mirabad
# Processing Record 42 of Set 12 | macduff
# Processing Record 43 of Set 12 | sergeyevka
# Processing Record 44 of Set 12 | eyl
# Processing Record 45 of Set 12 | skibbereen
# Processing Record 46 of Set 12 | ajdabiya
# Processing Record 47 of Set 12 | krasnoselkup
# Processing Record 48 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 49 of Set 12 | peniche
# Processing Record 50 of Set 12 | alakurtti
# Processing Record 1 of Set 13 | ampanihy
# Processing Record 2 of Set 13 | igdir
# Processing Record 3 of Set 13 | janow lubelski
# Processing Record 4 of Set 13 | los andes
# Processing Record 5 of Set 13 | chicama
# Processing Record 6 of Set 13 | marsaxlokk
# Processing Record 7 of Set 13 | lieksa
# Processing Record 8 of Set 13 | albanel
# Processing Record 9 of Set 13 | kemijarvi
# Processing Record 10 of Set 13 | vila do maio
# Processing Record 11 of Set 13 | debica
# Processing Record 12 of Set 13 | mehtar lam
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Length of our array (> 500 would be good)
len(city_data)
# Out:
# 563

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0            Pisco -13.7000 -76.2167     69.03        88          75
# 1             Chuy -33.6971 -53.4616     71.15        74         100
# 2     Punta Arenas -53.1500 -70.9167     57.31        58          75
# 3  Arraial Do Cabo -22.9661 -42.0278     80.56        69          20
# 4         Coquimbo -29.9533 -71.3436     64.13        77          75
# 5           Rincon  32.2960 -81.2354     44.85        95          90
# 6           Rawson -43.3002 -65.1023     66.27        59           0
# 7           Dikson  73.5069  80.5464    -26.99        96         100
# 8         Baherden  38.4362  57.4316     61.27        34           0
# 9      Port Alfred -33.5906  26.8910     76.66        74          95
#
#    Wind Speed Country                 Date
# 0        1.14      PE  2021-12-21 13:20:08
# 1        4.03      UY  2021-12-21 13:20:08
# 2       37.98      CL  2021-12-21 13:19:07
# 3       14.97      BR  2021-12-21 13:20:08
# 4        5.75      CL  2021-12-21 13:20:09
# 5        8.05      US  2021-12-21 13:20:09
# 6       26.17      AR  2021-12-21 13:20:09
# 7       14.88      RU  2021-12-21 13:20:10
# 8       12.46      TM  2021-12-21 13:20:10
# 9       24.79      ZA  2021-12-21 13:20:10

# %%
# Reorder the columns
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#               City Country                 Date      Lat      Lng  Max Temp  \
# 0            Pisco      PE  2021-12-21 13:20:08 -13.7000 -76.2167     69.03
# 1             Chuy      UY  2021-12-21 13:20:08 -33.6971 -53.4616     71.15
# 2     Punta Arenas      CL  2021-12-21 13:19:07 -53.1500 -70.9167     57.31
# 3  Arraial Do Cabo      BR  2021-12-21 13:20:08 -22.9661 -42.0278     80.56
# 4         Coquimbo      CL  2021-12-21 13:20:09 -29.9533 -71.3436     64.13
#
#    Humidity  Cloudiness  Wind Speed
# 0        88          75        1.14
# 1        74         100        4.03
# 2        58          75       37.98
# 3        69          20       14.97
# 4        77          75        5.75

# %%
# Create the output file (CSV)
output_data_file = "Weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Create scatter plot for latitude vs. max temperature.
plt.scatter(lats, max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Create scatter plot for latitude vs. humidity.
plt.scatter(lats, humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig2.png")

# Show plot.
plt.show()

# %%
# Create scatter plot for latitude vs. cloudiness.
plt.scatter(lats, cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig3.png")

# Show plot.
plt.show()

# %%
# Create scatter plot for latitude vs. wind speed.
plt.scatter(lats, wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig4.png")

# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# %%
# Create function to create perform linear regression on weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    
    # Get equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Create scatter plot and plot regression line.
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r")
    
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
# information for a random city (index number 13)
index13 = city_data_df.loc[13]
index13
# Out:
# City           Puerto Del Rosario
# Country                        ES
# Date          2021-12-21 13:20:12
# Lat                       28.5004
# Lng                      -13.8627
# Max Temp                    76.75
# Humidity                       44
# Cloudiness                     20
# Wind Speed                  14.97
# Name: 13, dtype: object

# %%
# testing to get cities in northern hemisphere
city_data_df["Lat"] >= 0
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 558     True
# 559     True
# 560     True
# 561     True
# 562     True
# Name: Lat, Length: 563, dtype: bool

# %%
# first few citiies in northern hemisphere
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#            City Country                 Date      Lat      Lng  Max Temp  \
# 5        Rincon      US  2021-12-21 13:20:09  32.2960 -81.2354     44.85
# 7        Dikson      RU  2021-12-21 13:20:10  73.5069  80.5464    -26.99
# 8      Baherden      TM  2021-12-21 13:20:10  38.4362  57.4316     61.27
# 10      Botwood      CA  2021-12-21 13:20:11  49.1499 -55.3482     20.68
# 11  Dmitriyevka      RU  2021-12-21 13:20:11  54.7500  55.3333     31.55
#
#     Humidity  Cloudiness  Wind Speed
# 5         95          90        8.05
# 7         96         100       14.88
# 8         34           0       12.46
# 10        92         100        5.79
# 11        98         100        6.24

# %%
# Creating north/south Hemisphere dataframes.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression of the Northern Hemisphere (Max temp)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

#Call the function.
plot_linear_regression(x_values, y_values,
                      'Linear Regression of the Northern Hemisphere for Maximum Temperature', 'Max Temp', (40, 90))

# %%
# Linear regression of the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

#Call the function.
plot_linear_regression(x_values, y_values,
                      'Linear Regression of the Southern Hemisphere for Maximum Temperature', 'Max Temp', (-30, 52))

# %%
# Linear regression of the Northern Hemisphere (% Humidity)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

#Call the function.
plot_linear_regression(x_values, y_values,
                      'Linear Regression of the Northern Hemisphere for % Humidity', 'Humidity', (42, 15))

# %%
# Linear regression of the Southern Hemisphere (% Humidity)
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

#Call the function.
plot_linear_regression(x_values, y_values,
                      'Linear Regression of the Southern Hemisphere for % Humidity', 'Humidity', (-55, 95))

# %%
# Linear regression of the Northern Hemisphere (Cloudiness)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

#Call the function.
plot_linear_regression(x_values, y_values,
                      'Linear Regression of the Northern Hemisphere for Cloudiness', 'Cloudiness', (45, 14))

# %%
# Linear regression of the Southern Hemisphere (Cloudiness)
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

#Call the function.
plot_linear_regression(x_values, y_values,
                      'Linear Regression of the Southern Hemisphere for Cloudiness', 'Cloudiness', (-55, 66))

# %%
# Linear regression of the Northern Hemisphere (Wind Speed)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

#Call the function.
plot_linear_regression(x_values, y_values,
                      'Linear Regression of the Northern Hemisphere for Wind Speed', 'Wind Speed', (0, 30))

# %%
# Linear regression of the Southern Hemisphere (Wind Speed)
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

#Call the function.
plot_linear_regression(x_values, y_values,
                      'Linear Regression of the Southern Hemisphere for Wind Speed', 'Wind Speed', (-25, 35))
