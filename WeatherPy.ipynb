# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create sets of random latitudes and longitudes.
lats = np.random.uniform(low=-90, high=90, size=1500)
lngs = np.random.uniform(low=-90, high=90, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holidng cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for i in coordinates:
    city = citipy.nearest_city(i[0], i[1]).city_name
    
    # IF city is unique, add to list.
    if city not in cities:
        cities.append(city)
# Print city count to confirm sufficient count.
len(cities)
# Out:
# 622

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an endpoint URL for a city.
#city_url = url + "&q=" + "city"

# %%
# import the time library and the datetime module from the dattime library
import time
from datetime import datetime

# %%
# declare empty list
city_data = []
# print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# loop through all the cities in the list.
# enumerate iterates through list of citiies and retrieves both the index and city name from the list
for i, city in enumerate(cities):
    
    # Group citiies in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | arraial do cabo
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | afua
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | kayes
# Processing Record 6 of Set 1 | locri
# Processing Record 7 of Set 1 | kruisfontein
# Processing Record 8 of Set 1 | caucaia
# Processing Record 9 of Set 1 | la asuncion
# Processing Record 10 of Set 1 | cabedelo
# Processing Record 11 of Set 1 | vila franca do campo
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | lebu
# Processing Record 14 of Set 1 | hermanus
# Processing Record 15 of Set 1 | puerto del rosario
# Processing Record 16 of Set 1 | sumbe
# Processing Record 17 of Set 1 | kegayli
# City not found. Skipping...
# Processing Record 18 of Set 1 | goma
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | picota
# Processing Record 22 of Set 1 | bredasdorp
# ...

# %%
# Length of our array (> 500 would be good)
len(city_data)
# Out:
# 576

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0  Arraial Do Cabo -22.9661 -42.0278     91.36        62           0
# 1          Ushuaia -54.8000 -68.3000     55.02        50           0
# 2             Afua  -0.1567 -50.3867     84.24        74          86
# 3      Port Alfred -33.5906  26.8910     69.62        90          94
# 4            Kayes  14.0000 -11.0000     89.06        10          83
# 5            Locri  38.2414  16.2623     57.24        84          48
# 6     Kruisfontein -34.0033  24.7314     66.88        90         100
# 7          Caucaia  -3.7361 -38.6531     87.75        73          75
# 8      La Asuncion  11.0333 -63.8628     83.93        79          57
# 9         Cabedelo  -6.9811 -34.8339     86.67        70          58
#
#    Wind Speed Country                 Date
# 0       13.80      BR  2021-12-22 17:38:51
# 1       17.27      AR  2021-12-22 17:36:34
# 2        7.94      BR  2021-12-22 17:38:52
# ...

# %%
# Reorder the columns
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#               City Country                 Date      Lat      Lng  Max Temp  \
# 0  Arraial Do Cabo      BR  2021-12-22 17:38:51 -22.9661 -42.0278     91.36
# 1          Ushuaia      AR  2021-12-22 17:36:34 -54.8000 -68.3000     55.02
# 2             Afua      BR  2021-12-22 17:38:52  -0.1567 -50.3867     84.24
# 3      Port Alfred      ZA  2021-12-22 17:38:52 -33.5906  26.8910     69.62
# 4            Kayes      ML  2021-12-22 17:38:52  14.0000 -11.0000     89.06
#
#    Humidity  Cloudiness  Wind Speed
# 0        62           0       13.80
# 1        50           0       17.27
# 2        74          86        7.94
# 3        90          94        9.80
# 4        10          83       10.58

# %%
# Create the output file (CSV)
output_data_file = "Weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Create scatter plot for latitude vs. max temperature.
plt.scatter(lats, max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Create scatter plot for latitude vs. humidity.
plt.scatter(lats, humidity,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig2.png")

# Show plot.
plt.show()

# %%
# Create scatter plot for latitude vs. cloudiness.
plt.scatter(lats, cloudiness,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig3.png")

# Show plot.
plt.show()

# %%
# Create scatter plot for latitude vs. wind speed.
plt.scatter(lats, wind_speed,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig4.png")

# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# %%
# Create function to create perform linear regression on weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    
    # Get equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    # Create scatter plot and plot regression line.
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r")
    
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
# information for a random city (index number 13)
index13 = city_data_df.loc[13]
index13
# Out:
# City                     Hermanus
# Country                        ZA
# Date          2021-12-22 17:38:55
# Lat                      -34.4187
# Lng                       19.2345
# Max Temp                     73.9
# Humidity                       78
# Cloudiness                     49
# Wind Speed                  17.18
# Name: 13, dtype: object

# %%
# testing to get cities in northern hemisphere
city_data_df["Lat"] >= 0
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 571     True
# 572    False
# 573     True
# 574    False
# 575     True
# Name: Lat, Length: 576, dtype: bool

# %%
# first few citiies in northern hemisphere
city_data_df.loc[(city_data_df["Lat"] >= 0)].head()
# Out:
#                     City Country                 Date      Lat      Lng  \
# 4                  Kayes      ML  2021-12-22 17:38:52  14.0000 -11.0000
# 5                  Locri      IT  2021-12-22 17:38:53  38.2414  16.2623
# 8            La Asuncion      VE  2021-12-22 17:38:54  11.0333 -63.8628
# 10  Vila Franca Do Campo      PT  2021-12-22 17:38:55  37.7167 -25.4333
# 14    Puerto Del Rosario      ES  2021-12-22 17:38:56  28.5004 -13.8627
#
#     Max Temp  Humidity  Cloudiness  Wind Speed
# 4      89.06        10          83       10.58
# 5      57.24        84          48        2.53
# 8      83.93        79          57       18.41
# 10     61.21        72          90       18.19
# 14     71.28        78          20        4.61

# %%
# Creating north/south Hemisphere dataframes.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression of the Northern Hemisphere (Max temp)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

#Call the function.
plot_linear_regression(x_values, y_values,
                      'Linear Regression of the Northern Hemisphere for Maximum Temperature', 'Max Temp', (40, 90))

# %%
# Linear regression of the Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

#Call the function.
plot_linear_regression(x_values, y_values,
                      'Linear Regression of the Southern Hemisphere for Maximum Temperature', 'Max Temp', (-30, 52))

# %%
# Linear regression of the Northern Hemisphere (% Humidity)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

#Call the function.
plot_linear_regression(x_values, y_values,
                      'Linear Regression of the Northern Hemisphere for % Humidity', 'Humidity', (42, 15))

# %%
# Linear regression of the Southern Hemisphere (% Humidity)
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

#Call the function.
plot_linear_regression(x_values, y_values,
                      'Linear Regression of the Southern Hemisphere for % Humidity', 'Humidity', (-55, 15))

# %%
# Linear regression of the Northern Hemisphere (Cloudiness)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

#Call the function.
plot_linear_regression(x_values, y_values,
                      'Linear Regression of the Northern Hemisphere for Cloudiness', 'Cloudiness', (46, 54))

# %%
# Linear regression of the Southern Hemisphere (Cloudiness)
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

#Call the function.
plot_linear_regression(x_values, y_values,
                      'Linear Regression of the Southern Hemisphere for Cloudiness', 'Cloudiness', (-55, 55))

# %%
# Linear regression of the Northern Hemisphere (Wind Speed)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

#Call the function.
plot_linear_regression(x_values, y_values,
                      'Linear Regression of the Northern Hemisphere for Wind Speed', 'Wind Speed', (0, 30))

# %%
# Linear regression of the Southern Hemisphere (Wind Speed)
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

#Call the function.
plot_linear_regression(x_values, y_values,
                      'Linear Regression of the Southern Hemisphere for Wind Speed', 'Wind Speed', (-55, 20))
