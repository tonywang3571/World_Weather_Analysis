# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create sets of random latitudes and longitudes.
lats = np.random.uniform(low=-90, high=90, size=2000)
lngs = np.random.uniform(low=-90, high=90, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holidng cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for i in coordinates:
    city = citipy.nearest_city(i[0], i[1]).city_name
    
    # IF city is unique, add to list.
    if city not in cities:
        cities.append(city)
# Print city count to confirm sufficient count.
len(cities)
# Out:
# 772

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create an endpoint URL for a city.
#city_url = url + "&q=" + "city"

# %%
# import the time library and the datetime module from the dattime library
import time
from datetime import datetime

# %%
# declare empty list
city_data = []
# print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# loop through all the cities in the list.
# enumerate iterates through list of citiies and retrieves both the index and city name from the list
for i, city in enumerate(cities):
    
    # Group citiies in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        current_weather = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": current_weather,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | mar del plata
# Processing Record 2 of Set 1 | georgetown
# Processing Record 3 of Set 1 | gwadar
# Processing Record 4 of Set 1 | oksfjord
# Processing Record 5 of Set 1 | montecristo
# Processing Record 6 of Set 1 | campos novos
# Processing Record 7 of Set 1 | bonavista
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | lucea
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 1 | oranjemund
# Processing Record 12 of Set 1 | melilla
# Processing Record 13 of Set 1 | necochea
# Processing Record 14 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | the valley
# Processing Record 17 of Set 1 | ayni
# Processing Record 18 of Set 1 | porbandar
# Processing Record 19 of Set 1 | jacareacanga
# Processing Record 20 of Set 1 | menongue
# Processing Record 21 of Set 1 | qaanaaq
# Processing Record 22 of Set 1 | saint-philippe
# Processing Record 23 of Set 1 | minab
# Processing Record 24 of Set 1 | morondava
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | chadiza
# Processing Record 27 of Set 1 | valparaiso
# Processing Record 28 of Set 1 | longyearbyen
# Processing Record 29 of Set 1 | mahebourg
# Processing Record 30 of Set 1 | fauske
# Processing Record 31 of Set 1 | axim
# Processing Record 32 of Set 1 | vytegra
# Processing Record 33 of Set 1 | chuy
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | taoudenni
# Processing Record 36 of Set 1 | aksarka
# Processing Record 37 of Set 1 | ribeira grande
# Processing Record 38 of Set 1 | port elizabeth
# Processing Record 39 of Set 1 | naranjal
# Processing Record 40 of Set 1 | candia
# Processing Record 41 of Set 1 | aguas belas
# Processing Record 42 of Set 1 | rio gallegos
# Processing Record 43 of Set 1 | santa isabel do rio negro
# Processing Record 44 of Set 1 | bengkulu
# Processing Record 45 of Set 1 | pokhara
# Processing Record 46 of Set 1 | meulaboh
# Processing Record 47 of Set 1 | nantucket
# Processing Record 48 of Set 1 | key west
# Processing Record 49 of Set 1 | gazli
# Processing Record 50 of Set 1 | torbay
# Processing Record 1 of Set 2 | port-gentil
# Processing Record 2 of Set 2 | panguipulli
# Processing Record 3 of Set 2 | kamenka
# Processing Record 4 of Set 2 | margate
# Processing Record 5 of Set 2 | victoria
# Processing Record 6 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 2 | temyasovo
# Processing Record 8 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | tyristrand
# Processing Record 11 of Set 2 | sidrolandia
# Processing Record 12 of Set 2 | ilulissat
# Processing Record 13 of Set 2 | wageningen
# Processing Record 14 of Set 2 | camana
# Processing Record 15 of Set 2 | dikson
# Processing Record 16 of Set 2 | nusaybin
# Processing Record 17 of Set 2 | santo antonio do ica
# Processing Record 18 of Set 2 | desenzano del garda
# Processing Record 19 of Set 2 | sao filipe
# Processing Record 20 of Set 2 | obidos
# Processing Record 21 of Set 2 | paamiut
# Processing Record 22 of Set 2 | bredasdorp
# Processing Record 23 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 2 | mariara
# Processing Record 25 of Set 2 | leirvik
# Processing Record 26 of Set 2 | el badari
# City not found. Skipping...
# Processing Record 27 of Set 2 | east london
# Processing Record 28 of Set 2 | busselton
# Processing Record 29 of Set 2 | kyzyl-suu
# Processing Record 30 of Set 2 | muros
# Processing Record 31 of Set 2 | laguna
# Processing Record 32 of Set 2 | saint-louis
# Processing Record 33 of Set 2 | lebu
# Processing Record 34 of Set 2 | wajid
# Processing Record 35 of Set 2 | zlitan
# Processing Record 36 of Set 2 | nouadhibou
# Processing Record 37 of Set 2 | narsaq
# Processing Record 38 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 39 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 2 | manacapuru
# Processing Record 41 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 2 | birao
# Processing Record 43 of Set 2 | ciudad bolivar
# Processing Record 44 of Set 2 | tapaua
# City not found. Skipping...
# Processing Record 45 of Set 2 | koplik
# Processing Record 46 of Set 2 | mutsamudu
# City not found. Skipping...
# Processing Record 47 of Set 2 | belmonte
# Processing Record 48 of Set 2 | ferrol
# Processing Record 49 of Set 2 | bathsheba
# Processing Record 50 of Set 2 | naftah
# City not found. Skipping...
# Processing Record 1 of Set 3 | nadym
# Processing Record 2 of Set 3 | port-cartier
# Processing Record 3 of Set 3 | umm lajj
# Processing Record 4 of Set 3 | jamestown
# Processing Record 5 of Set 3 | hambantota
# Processing Record 6 of Set 3 | mogadishu
# Processing Record 7 of Set 3 | de aar
# Processing Record 8 of Set 3 | surt
# Processing Record 9 of Set 3 | grindavik
# Processing Record 10 of Set 3 | cidreira
# Processing Record 11 of Set 3 | hithadhoo
# Processing Record 12 of Set 3 | carauari
# Processing Record 13 of Set 3 | kodoli
# Processing Record 14 of Set 3 | ashqelon
# Processing Record 15 of Set 3 | sept-iles
# Processing Record 16 of Set 3 | bardiyah
# Processing Record 17 of Set 3 | kruisfontein
# Processing Record 18 of Set 3 | oparino
# Processing Record 19 of Set 3 | cayenne
# Processing Record 20 of Set 3 | joniskis
# Processing Record 21 of Set 3 | rundu
# Processing Record 22 of Set 3 | nema
# Processing Record 23 of Set 3 | saldanha
# Processing Record 24 of Set 3 | bombay
# Processing Record 25 of Set 3 | nanortalik
# Processing Record 26 of Set 3 | viedma
# Processing Record 27 of Set 3 | touros
# Processing Record 28 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 3 | vardo
# Processing Record 30 of Set 3 | havoysund
# Processing Record 31 of Set 3 | bulancak
# Processing Record 32 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 3 | castro
# Processing Record 34 of Set 3 | kashi
# Processing Record 35 of Set 3 | puerto del rosario
# Processing Record 36 of Set 3 | bubaque
# Processing Record 37 of Set 3 | atar
# Processing Record 38 of Set 3 | iqaluit
# Processing Record 39 of Set 3 | oneida
# Processing Record 40 of Set 3 | atbasar
# Processing Record 41 of Set 3 | peto
# Processing Record 42 of Set 3 | catamarca
# Processing Record 43 of Set 3 | souillac
# Processing Record 44 of Set 3 | khandbari
# Processing Record 45 of Set 3 | takoradi
# Processing Record 46 of Set 3 | henties bay
# Processing Record 47 of Set 3 | vestmannaeyjar
# Processing Record 48 of Set 3 | marrakesh
# Processing Record 49 of Set 3 | benghazi
# Processing Record 50 of Set 3 | zhetybay
# City not found. Skipping...
# Processing Record 1 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 4 | hofn
# Processing Record 3 of Set 4 | chapleau
# Processing Record 4 of Set 4 | coihaique
# Processing Record 5 of Set 4 | chapais
# Processing Record 6 of Set 4 | sredec
# City not found. Skipping...
# Processing Record 7 of Set 4 | tromso
# Processing Record 8 of Set 4 | santa maria
# Processing Record 9 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 4 | itarema
# Processing Record 11 of Set 4 | qunduz
# Processing Record 12 of Set 4 | kudahuvadhoo
# Processing Record 13 of Set 4 | mpongwe
# Processing Record 14 of Set 4 | troitskoye
# Processing Record 15 of Set 4 | saint-paul
# Processing Record 16 of Set 4 | barawe
# City not found. Skipping...
# Processing Record 17 of Set 4 | cockburn town
# Processing Record 18 of Set 4 | giyani
# Processing Record 19 of Set 4 | stornoway
# Processing Record 20 of Set 4 | adre
# Processing Record 21 of Set 4 | nchelenge
# Processing Record 22 of Set 4 | saint-pierre
# Processing Record 23 of Set 4 | faya
# Processing Record 24 of Set 4 | karaton
# Processing Record 25 of Set 4 | lagoa
# Processing Record 26 of Set 4 | kjollefjord
# Processing Record 27 of Set 4 | vwawa
# Processing Record 28 of Set 4 | vila velha
# Processing Record 29 of Set 4 | opatija
# Processing Record 30 of Set 4 | dalbandin
# Processing Record 31 of Set 4 | tapa
# Processing Record 32 of Set 4 | youghal
# Processing Record 33 of Set 4 | varkkallai
# Processing Record 34 of Set 4 | machico
# Processing Record 35 of Set 4 | upernavik
# Processing Record 36 of Set 4 | muisne
# Processing Record 37 of Set 4 | pontypool
# Processing Record 38 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 39 of Set 4 | hwange
# Processing Record 40 of Set 4 | kharan
# Processing Record 41 of Set 4 | agirish
# Processing Record 42 of Set 4 | tasiilaq
# Processing Record 43 of Set 4 | maldonado
# Processing Record 44 of Set 4 | kovur
# Processing Record 45 of Set 4 | tabou
# Processing Record 46 of Set 4 | olafsvik
# Processing Record 47 of Set 4 | castrillon
# Processing Record 48 of Set 4 | troitsko-pechorsk
# Processing Record 49 of Set 4 | namibe
# Processing Record 50 of Set 4 | borujan
# City not found. Skipping...
# Processing Record 1 of Set 5 | ikot ekpene
# Processing Record 2 of Set 5 | comodoro rivadavia
# Processing Record 3 of Set 5 | turukhansk
# Processing Record 4 of Set 5 | berea
# Processing Record 5 of Set 5 | astolfo dutra
# Processing Record 6 of Set 5 | mulchen
# Processing Record 7 of Set 5 | los llanos de aridane
# Processing Record 8 of Set 5 | rocha
# Processing Record 9 of Set 5 | wattegama
# Processing Record 10 of Set 5 | ponta do sol
# Processing Record 11 of Set 5 | caravelas
# Processing Record 12 of Set 5 | matagami
# Processing Record 13 of Set 5 | ekibastuz
# Processing Record 14 of Set 5 | panorama
# Processing Record 15 of Set 5 | awbari
# Processing Record 16 of Set 5 | arraial do cabo
# Processing Record 17 of Set 5 | codrington
# Processing Record 18 of Set 5 | callander
# Processing Record 19 of Set 5 | honningsvag
# Processing Record 20 of Set 5 | zychlin
# Processing Record 21 of Set 5 | sisimiut
# Processing Record 22 of Set 5 | chiredzi
# Processing Record 23 of Set 5 | fougeres
# Processing Record 24 of Set 5 | muzhappilangad
# City not found. Skipping...
# Processing Record 25 of Set 5 | chala
# Processing Record 26 of Set 5 | kristinehamn
# Processing Record 27 of Set 5 | puksoozero
# Processing Record 28 of Set 5 | nyuksenitsa
# Processing Record 29 of Set 5 | iaciara
# Processing Record 30 of Set 5 | ushtobe
# Processing Record 31 of Set 5 | bambous virieux
# Processing Record 32 of Set 5 | shelburne
# Processing Record 33 of Set 5 | yar-sale
# Processing Record 34 of Set 5 | hamilton
# Processing Record 35 of Set 5 | abha
# Processing Record 36 of Set 5 | aden
# Processing Record 37 of Set 5 | titlagarh
# Processing Record 38 of Set 5 | brandfort
# Processing Record 39 of Set 5 | douglas
# Processing Record 40 of Set 5 | saint george
# Processing Record 41 of Set 5 | clyde river
# Processing Record 42 of Set 5 | coquimbo
# Processing Record 43 of Set 5 | aswan
# Processing Record 44 of Set 5 | kavaratti
# Processing Record 45 of Set 5 | benguela
# Processing Record 46 of Set 5 | saint-francois
# Processing Record 47 of Set 5 | toksovo
# Processing Record 48 of Set 5 | ati
# Processing Record 49 of Set 5 | minsk
# Processing Record 50 of Set 5 | boa vista
# Processing Record 1 of Set 6 | buraydah
# Processing Record 2 of Set 6 | kapoeta
# Processing Record 3 of Set 6 | kozhevnikovo
# Processing Record 4 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 6 | galle
# Processing Record 6 of Set 6 | dzhusaly
# City not found. Skipping...
# Processing Record 7 of Set 6 | igrim
# Processing Record 8 of Set 6 | mao
# Processing Record 9 of Set 6 | rudnichnyy
# Processing Record 10 of Set 6 | jalu
# Processing Record 11 of Set 6 | sarakhs
# Processing Record 12 of Set 6 | bereda
# Processing Record 13 of Set 6 | zabid
# Processing Record 14 of Set 6 | derzhavinsk
# Processing Record 15 of Set 6 | altay
# Processing Record 16 of Set 6 | luderitz
# Processing Record 17 of Set 6 | barranca
# Processing Record 18 of Set 6 | la mana
# Processing Record 19 of Set 6 | santa cruz
# Processing Record 20 of Set 6 | busayra
# Processing Record 21 of Set 6 | tripoli
# Processing Record 22 of Set 6 | aktau
# Processing Record 23 of Set 6 | sanford
# Processing Record 24 of Set 6 | vilhena
# Processing Record 25 of Set 6 | carnarvon
# Processing Record 26 of Set 6 | medenychi
# Processing Record 27 of Set 6 | santiago del estero
# Processing Record 28 of Set 6 | rawson
# Processing Record 29 of Set 6 | sar-e pul
# Processing Record 30 of Set 6 | nisia floresta
# Processing Record 31 of Set 6 | maragogi
# Processing Record 32 of Set 6 | hargeysa
# Processing Record 33 of Set 6 | znamenskoye
# Processing Record 34 of Set 6 | siavonga
# Processing Record 35 of Set 6 | muravlenko
# Processing Record 36 of Set 6 | jalingo
# Processing Record 37 of Set 6 | tahta
# Processing Record 38 of Set 6 | chicama
# Processing Record 39 of Set 6 | arlit
# Processing Record 40 of Set 6 | marsabit
# Processing Record 41 of Set 6 | tefe
# Processing Record 42 of Set 6 | bandarbeyla
# Processing Record 43 of Set 6 | manoel urbano
# Processing Record 44 of Set 6 | vestmanna
# Processing Record 45 of Set 6 | yushala
# Processing Record 46 of Set 6 | tytuvenai
# Processing Record 47 of Set 6 | barcelos
# Processing Record 48 of Set 6 | umm kaddadah
# Processing Record 49 of Set 6 | plouzane
# Processing Record 50 of Set 6 | mizdah
# Processing Record 1 of Set 7 | villa carlos paz
# Processing Record 2 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 3 of Set 7 | mwene-ditu
# Processing Record 4 of Set 7 | penaflor
# Processing Record 5 of Set 7 | raga
# Processing Record 6 of Set 7 | qandala
# Processing Record 7 of Set 7 | richards bay
# Processing Record 8 of Set 7 | aksu
# Processing Record 9 of Set 7 | sur
# Processing Record 10 of Set 7 | thompson
# Processing Record 11 of Set 7 | sylacauga
# Processing Record 12 of Set 7 | zaranj
# Processing Record 13 of Set 7 | dingle
# Processing Record 14 of Set 7 | burica
# City not found. Skipping...
# Processing Record 15 of Set 7 | tikamgarh
# Processing Record 16 of Set 7 | koudougou
# Processing Record 17 of Set 7 | zaraza
# Processing Record 18 of Set 7 | kokkola
# Processing Record 19 of Set 7 | kem
# Processing Record 20 of Set 7 | ipixuna
# Processing Record 21 of Set 7 | ivybridge
# Processing Record 22 of Set 7 | lar gerd
# City not found. Skipping...
# Processing Record 23 of Set 7 | havre-saint-pierre
# Processing Record 24 of Set 7 | kourou
# Processing Record 25 of Set 7 | massakory
# Processing Record 26 of Set 7 | vila franca do campo
# Processing Record 27 of Set 7 | dakoro
# Processing Record 28 of Set 7 | chimoio
# Processing Record 29 of Set 7 | cordele
# Processing Record 30 of Set 7 | bam
# Processing Record 31 of Set 7 | salalah
# Processing Record 32 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 33 of Set 7 | shiraz
# Processing Record 34 of Set 7 | pisco
# Processing Record 35 of Set 7 | brae
# Processing Record 36 of Set 7 | jujuy
# City not found. Skipping...
# Processing Record 37 of Set 7 | ostrovnoy
# Processing Record 38 of Set 7 | lakselv
# Processing Record 39 of Set 7 | xuddur
# Processing Record 40 of Set 7 | goderich
# Processing Record 41 of Set 7 | fairmont
# Processing Record 42 of Set 7 | sinnamary
# Processing Record 43 of Set 7 | mahanoro
# Processing Record 44 of Set 7 | san andres
# Processing Record 45 of Set 7 | omboue
# Processing Record 46 of Set 7 | pangnirtung
# Processing Record 47 of Set 7 | joue-les-tours
# Processing Record 48 of Set 7 | camacha
# Processing Record 49 of Set 7 | mangan
# Processing Record 50 of Set 7 | bousso
# Processing Record 1 of Set 8 | shubarkuduk
# Processing Record 2 of Set 8 | sabha
# Processing Record 3 of Set 8 | santo tomas
# Processing Record 4 of Set 8 | mehamn
# Processing Record 5 of Set 8 | ulu-telyak
# Processing Record 6 of Set 8 | kutum
# Processing Record 7 of Set 8 | ugoofaaru
# Processing Record 8 of Set 8 | saint-joseph
# Processing Record 9 of Set 8 | neuquen
# Processing Record 10 of Set 8 | sayyan
# Processing Record 11 of Set 8 | puerto ayacucho
# Processing Record 12 of Set 8 | krasnovishersk
# Processing Record 13 of Set 8 | manono
# Processing Record 14 of Set 8 | semey
# Processing Record 15 of Set 8 | teeli
# Processing Record 16 of Set 8 | atocha
# Processing Record 17 of Set 8 | somovo
# Processing Record 18 of Set 8 | tallahassee
# Processing Record 19 of Set 8 | klaksvik
# Processing Record 20 of Set 8 | damavand
# Processing Record 21 of Set 8 | saint anthony
# Processing Record 22 of Set 8 | rameswaram
# Processing Record 23 of Set 8 | mandiana
# Processing Record 24 of Set 8 | xai-xai
# Processing Record 25 of Set 8 | berlevag
# Processing Record 26 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 27 of Set 8 | malegaon
# Processing Record 28 of Set 8 | cap-aux-meules
# Processing Record 29 of Set 8 | krasnoselkup
# Processing Record 30 of Set 8 | manavalakurichi
# Processing Record 31 of Set 8 | trojes
# Processing Record 32 of Set 8 | marsh harbour
# Processing Record 33 of Set 8 | irece
# Processing Record 34 of Set 8 | eregli
# Processing Record 35 of Set 8 | dagana
# Processing Record 36 of Set 8 | cap malheureux
# Processing Record 37 of Set 8 | luena
# Processing Record 38 of Set 8 | jaisalmer
# Processing Record 39 of Set 8 | palora
# Processing Record 40 of Set 8 | guaruja
# Processing Record 41 of Set 8 | darnah
# Processing Record 42 of Set 8 | bestobe
# Processing Record 43 of Set 8 | phalodi
# Processing Record 44 of Set 8 | rio grande
# Processing Record 45 of Set 8 | bar harbor
# Processing Record 46 of Set 8 | hurghada
# Processing Record 47 of Set 8 | afyonkarahisar
# Processing Record 48 of Set 8 | mercedes
# Processing Record 49 of Set 8 | quatre cocos
# Processing Record 50 of Set 8 | kadoma
# Processing Record 1 of Set 9 | solnechnoye
# Processing Record 2 of Set 9 | burgos
# Processing Record 3 of Set 9 | rostock
# Processing Record 4 of Set 9 | saint-augustin
# Processing Record 5 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 9 | mitsamiouli
# Processing Record 7 of Set 9 | alta floresta
# Processing Record 8 of Set 9 | usinsk
# Processing Record 9 of Set 9 | uni
# Processing Record 10 of Set 9 | lalsot
# Processing Record 11 of Set 9 | isla mujeres
# Processing Record 12 of Set 9 | zavodoukovsk
# Processing Record 13 of Set 9 | belyy yar
# Processing Record 14 of Set 9 | praia
# Processing Record 15 of Set 9 | tamandare
# Processing Record 16 of Set 9 | oshawa
# Processing Record 17 of Set 9 | salinas
# Processing Record 18 of Set 9 | pergamino
# Processing Record 19 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 20 of Set 9 | herat
# Processing Record 21 of Set 9 | bollnas
# Processing Record 22 of Set 9 | ancud
# Processing Record 23 of Set 9 | husavik
# Processing Record 24 of Set 9 | harper
# Processing Record 25 of Set 9 | sucua
# Processing Record 26 of Set 9 | tekeli
# Processing Record 27 of Set 9 | teguldet
# Processing Record 28 of Set 9 | senekal
# Processing Record 29 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 30 of Set 9 | rognedino
# Processing Record 31 of Set 9 | swellendam
# Processing Record 32 of Set 9 | sioux lookout
# Processing Record 33 of Set 9 | corinth
# Processing Record 34 of Set 9 | boffa
# Processing Record 35 of Set 9 | bossangoa
# Processing Record 36 of Set 9 | kitgum
# Processing Record 37 of Set 9 | bayevo
# Processing Record 38 of Set 9 | ninotsminda
# Processing Record 39 of Set 9 | karasjok
# Processing Record 40 of Set 9 | lethem
# Processing Record 41 of Set 9 | talitsy
# Processing Record 42 of Set 9 | nurota
# Processing Record 43 of Set 9 | husum
# Processing Record 44 of Set 9 | borborema
# Processing Record 45 of Set 9 | marawi
# Processing Record 46 of Set 9 | hobyo
# Processing Record 47 of Set 9 | kochinda
# Processing Record 48 of Set 9 | timra
# Processing Record 49 of Set 9 | vendome
# Processing Record 50 of Set 9 | soyo
# Processing Record 1 of Set 10 | taywarah
# Processing Record 2 of Set 10 | quepos
# Processing Record 3 of Set 10 | walvis bay
# Processing Record 4 of Set 10 | staryy nadym
# Processing Record 5 of Set 10 | marathon
# Processing Record 6 of Set 10 | bitkine
# Processing Record 7 of Set 10 | beloha
# Processing Record 8 of Set 10 | halifax
# Processing Record 9 of Set 10 | camabatela
# Processing Record 10 of Set 10 | pratapgarh
# Processing Record 11 of Set 10 | termoli
# Processing Record 12 of Set 10 | buta
# Processing Record 13 of Set 10 | gangawati
# Processing Record 14 of Set 10 | requena
# Processing Record 15 of Set 10 | malanje
# Processing Record 16 of Set 10 | puerto madryn
# Processing Record 17 of Set 10 | yarmouth
# Processing Record 18 of Set 10 | salaga
# Processing Record 19 of Set 10 | sinazongwe
# Processing Record 20 of Set 10 | porto santo
# Processing Record 21 of Set 10 | soroti
# Processing Record 22 of Set 10 | tabas
# Processing Record 23 of Set 10 | bonga
# Processing Record 24 of Set 10 | saint-georges
# Processing Record 25 of Set 10 | miandrivazo
# Processing Record 26 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 27 of Set 10 | rairangpur
# Processing Record 28 of Set 10 | acari
# Processing Record 29 of Set 10 | valdosta
# Processing Record 30 of Set 10 | shchuchye
# City not found. Skipping...
# Processing Record 31 of Set 10 | porto novo
# Processing Record 32 of Set 10 | kismayo
# Processing Record 33 of Set 10 | jumla
# Processing Record 34 of Set 10 | sorkjosen
# Processing Record 35 of Set 10 | parana
# Processing Record 36 of Set 10 | faro
# Processing Record 37 of Set 10 | taltal
# Processing Record 38 of Set 10 | guelengdeng
# City not found. Skipping...
# Processing Record 39 of Set 10 | usogorsk
# Processing Record 40 of Set 10 | yenagoa
# Processing Record 41 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 42 of Set 10 | general pico
# Processing Record 43 of Set 10 | kovdor
# Processing Record 44 of Set 10 | clarence town
# Processing Record 45 of Set 10 | piacabucu
# Processing Record 46 of Set 10 | coruripe
# Processing Record 47 of Set 10 | calama
# Processing Record 48 of Set 10 | harsin
# Processing Record 49 of Set 10 | bonthe
# Processing Record 50 of Set 10 | pedernales
# Processing Record 1 of Set 11 | mezen
# Processing Record 2 of Set 11 | mahibadhoo
# Processing Record 3 of Set 11 | douentza
# Processing Record 4 of Set 11 | makat
# Processing Record 5 of Set 11 | upington
# Processing Record 6 of Set 11 | pueblo bello
# Processing Record 7 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 8 of Set 11 | tiznit
# Processing Record 9 of Set 11 | verkhnyaya inta
# Processing Record 10 of Set 11 | roros
# Processing Record 11 of Set 11 | isiro
# Processing Record 12 of Set 11 | arrah
# Processing Record 13 of Set 11 | gao
# Processing Record 14 of Set 11 | amot
# Processing Record 15 of Set 11 | la loma
# Processing Record 16 of Set 11 | rzeszow
# Processing Record 17 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 18 of Set 11 | colesberg
# Processing Record 19 of Set 11 | veraval
# Processing Record 20 of Set 11 | callaway
# Processing Record 21 of Set 11 | itaituba
# Processing Record 22 of Set 11 | agbor
# Processing Record 23 of Set 11 | leua
# Processing Record 24 of Set 11 | gonaives
# Processing Record 25 of Set 11 | cartagena
# Processing Record 26 of Set 11 | cabinda
# Processing Record 27 of Set 11 | tignere
# Processing Record 28 of Set 11 | gat
# Processing Record 29 of Set 11 | turayf
# Processing Record 30 of Set 11 | male
# Processing Record 31 of Set 11 | bethanien
# Processing Record 32 of Set 11 | kralendijk
# Processing Record 33 of Set 11 | oistins
# Processing Record 34 of Set 11 | solano
# Processing Record 35 of Set 11 | quelimane
# Processing Record 36 of Set 11 | houma
# Processing Record 37 of Set 11 | hvide sande
# Processing Record 38 of Set 11 | soria
# Processing Record 39 of Set 11 | chaumont
# Processing Record 40 of Set 11 | garissa
# Processing Record 41 of Set 11 | pampierstad
# Processing Record 42 of Set 11 | aliwal north
# Processing Record 43 of Set 11 | boende
# Processing Record 44 of Set 11 | primorsk
# Processing Record 45 of Set 11 | bouafle
# Processing Record 46 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 47 of Set 11 | bhiwandi
# Processing Record 48 of Set 11 | urumqi
# Processing Record 49 of Set 11 | korcula
# Processing Record 50 of Set 11 | saurimo
# Processing Record 1 of Set 12 | oksovskiy
# Processing Record 2 of Set 12 | korem
# Processing Record 3 of Set 12 | zimovniki
# Processing Record 4 of Set 12 | chulumani
# Processing Record 5 of Set 12 | inhambane
# Processing Record 6 of Set 12 | nikolsk
# Processing Record 7 of Set 12 | timiryazevskiy
# Processing Record 8 of Set 12 | talcahuano
# Processing Record 9 of Set 12 | tarko-sale
# Processing Record 10 of Set 12 | dombarovskiy
# Processing Record 11 of Set 12 | dekar
# Processing Record 12 of Set 12 | porlamar
# Processing Record 13 of Set 12 | marsaxlokk
# Processing Record 14 of Set 12 | notodden
# Processing Record 15 of Set 12 | kisangani
# Processing Record 16 of Set 12 | svetlyy yar
# Processing Record 17 of Set 12 | lukovetskiy
# Processing Record 18 of Set 12 | yarim
# Processing Record 19 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 20 of Set 12 | raudeberg
# Processing Record 21 of Set 12 | huarmey
# Processing Record 22 of Set 12 | kedougou
# Processing Record 23 of Set 12 | ugra
# Processing Record 24 of Set 12 | vinukonda
# Processing Record 25 of Set 12 | jacqueville
# Processing Record 26 of Set 12 | dwarahat
# Processing Record 27 of Set 12 | penzance
# Processing Record 28 of Set 12 | novo aripuana
# Processing Record 29 of Set 12 | iringa
# Processing Record 30 of Set 12 | qostanay
# Processing Record 31 of Set 12 | greifswald
# Processing Record 32 of Set 12 | kambove
# Processing Record 33 of Set 12 | guarapari
# Processing Record 34 of Set 12 | opuwo
# Processing Record 35 of Set 12 | luis correia
# Processing Record 36 of Set 12 | zabol
# Processing Record 37 of Set 12 | ginir
# Processing Record 38 of Set 12 | bolshiye uki
# City not found. Skipping...
# Processing Record 39 of Set 12 | stokmarknes
# Processing Record 40 of Set 12 | gamba
# Processing Record 41 of Set 12 | kalanchak
# Processing Record 42 of Set 12 | novotroitskaya
# Processing Record 43 of Set 12 | rio branco
# Processing Record 44 of Set 12 | misratah
# Processing Record 45 of Set 12 | natal
# Processing Record 46 of Set 12 | llandrindod wells
# Processing Record 47 of Set 12 | nuuk
# Processing Record 48 of Set 12 | kangaatsiaq
# Processing Record 49 of Set 12 | shubarshi
# Processing Record 50 of Set 12 | port blair
# Processing Record 1 of Set 13 | dakar
# Processing Record 2 of Set 13 | tres arroyos
# Processing Record 3 of Set 13 | asayita
# City not found. Skipping...
# Processing Record 4 of Set 13 | san luis
# Processing Record 5 of Set 13 | salisbury
# Processing Record 6 of Set 13 | trairi
# Processing Record 7 of Set 13 | marsa matruh
# Processing Record 8 of Set 13 | jarjis
# City not found. Skipping...
# Processing Record 9 of Set 13 | rehoboth
# Processing Record 10 of Set 13 | tawkar
# City not found. Skipping...
# Processing Record 11 of Set 13 | albany
# Processing Record 12 of Set 13 | gaffney
# Processing Record 13 of Set 13 | talnakh
# Processing Record 14 of Set 13 | bushehr
# Processing Record 15 of Set 13 | dawlatabad
# Processing Record 16 of Set 13 | maarianhamina
# Processing Record 17 of Set 13 | okhansk
# Processing Record 18 of Set 13 | macas
# Processing Record 19 of Set 13 | cuenca
# Processing Record 20 of Set 13 | dunda
# Processing Record 21 of Set 13 | muli
# Processing Record 22 of Set 13 | puerto rico
# Processing Record 23 of Set 13 | pontes e lacerda
# Processing Record 24 of Set 13 | severnyy
# Processing Record 25 of Set 13 | ust-tsilma
# Processing Record 26 of Set 13 | bad doberan
# Processing Record 27 of Set 13 | mikkeli
# Processing Record 28 of Set 13 | bulungu
# Processing Record 29 of Set 13 | adrar
# Processing Record 30 of Set 13 | ardakan
# Processing Record 31 of Set 13 | san pancrazio salentino
# Processing Record 32 of Set 13 | kaduqli
# Processing Record 33 of Set 13 | aviles
# Processing Record 34 of Set 13 | iracoubo
# Processing Record 35 of Set 13 | carutapera
# Processing Record 36 of Set 13 | cururupu
# Processing Record 37 of Set 13 | iranshahr
# Processing Record 38 of Set 13 | curitibanos
# Processing Record 39 of Set 13 | kurchum
# Processing Record 40 of Set 13 | riyadh
# Processing Record 41 of Set 13 | padang
# Processing Record 42 of Set 13 | rio claro
# Processing Record 43 of Set 13 | uray
# Processing Record 44 of Set 13 | ponazyrevo
# Processing Record 45 of Set 13 | imbituba
# Processing Record 46 of Set 13 | kifri
# Processing Record 47 of Set 13 | caninde de sao francisco
# Processing Record 48 of Set 13 | kargil
# Processing Record 49 of Set 13 | grand gaube
# Processing Record 50 of Set 13 | umba
# Processing Record 1 of Set 14 | battle creek
# Processing Record 2 of Set 14 | kita
# Processing Record 3 of Set 14 | itacoatiara
# Processing Record 4 of Set 14 | plettenberg bay
# Processing Record 5 of Set 14 | camopi
# Processing Record 6 of Set 14 | canarana
# Processing Record 7 of Set 14 | tukrah
# Processing Record 8 of Set 14 | ierapetra
# Processing Record 9 of Set 14 | llano de piedra
# Processing Record 10 of Set 14 | didwana
# Processing Record 11 of Set 14 | bauta
# Processing Record 12 of Set 14 | lyuban
# Processing Record 13 of Set 14 | saraland
# Processing Record 14 of Set 14 | ormara
# Processing Record 15 of Set 14 | bosaso
# Processing Record 16 of Set 14 | easton
# Processing Record 17 of Set 14 | nagaur
# Processing Record 18 of Set 14 | petrokamenskoye
# Processing Record 19 of Set 14 | humaita
# Processing Record 20 of Set 14 | lagos
# Processing Record 21 of Set 14 | turinskaya sloboda
# Processing Record 22 of Set 14 | calamar
# Processing Record 23 of Set 14 | leh
# Processing Record 24 of Set 14 | dromolaxia
# Processing Record 25 of Set 14 | finnsnes
# Processing Record 26 of Set 14 | remanso
# Processing Record 27 of Set 14 | matameye
# City not found. Skipping...
# Processing Record 28 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 29 of Set 14 | deutschlandsberg
# Processing Record 30 of Set 14 | rye brook
# Processing Record 31 of Set 14 | staroye drozhzhanoye
# Processing Record 32 of Set 14 | gornopravdinsk
# Processing Record 33 of Set 14 | maniitsoq
# Processing Record 34 of Set 14 | ponta delgada
# Processing Record 35 of Set 14 | outjo
# Processing Record 36 of Set 14 | tamala
# Processing Record 37 of Set 14 | zapolyarnyy
# Processing Record 38 of Set 14 | dom pedrito
# Processing Record 39 of Set 14 | walcz
# Processing Record 40 of Set 14 | sorland
# Processing Record 41 of Set 14 | cancun
# Processing Record 42 of Set 14 | iguape
# Processing Record 43 of Set 14 | awjilah
# Processing Record 44 of Set 14 | aguimes
# Processing Record 45 of Set 14 | ampanihy
# Processing Record 46 of Set 14 | formosa
# Processing Record 47 of Set 14 | monrovia
# Processing Record 48 of Set 14 | sao felix do xingu
# Processing Record 49 of Set 14 | iskateley
# Processing Record 50 of Set 14 | estepona
# Processing Record 1 of Set 15 | mahajanga
# Processing Record 2 of Set 15 | kabalo
# Processing Record 3 of Set 15 | blois
# Processing Record 4 of Set 15 | sint-lievens-houtem
# Processing Record 5 of Set 15 | podporozhye
# Processing Record 6 of Set 15 | abapo
# Processing Record 7 of Set 15 | sabi
# Processing Record 8 of Set 15 | qom
# Processing Record 9 of Set 15 | andros town
# Processing Record 10 of Set 15 | qena
# Processing Record 11 of Set 15 | port shepstone
# Processing Record 12 of Set 15 | lerwick
# Processing Record 13 of Set 15 | jablah
# Processing Record 14 of Set 15 | perevoz
# Processing Record 15 of Set 15 | eucaliptus
# Processing Record 16 of Set 15 | abu dhabi
# Processing Record 17 of Set 15 | rognan
# Processing Record 18 of Set 15 | barra patuca
# Processing Record 19 of Set 15 | domoni
# Processing Record 20 of Set 15 | santa ana
# Processing Record 21 of Set 15 | khaniotis
# Processing Record 22 of Set 15 | bodden town
# Processing Record 23 of Set 15 | pula
# Processing Record 24 of Set 15 | trofors
# Processing Record 25 of Set 15 | yuzhnyy
# Processing Record 26 of Set 15 | anthia
# City not found. Skipping...
# Processing Record 27 of Set 15 | ust-koksa
# Processing Record 28 of Set 15 | mastic beach
# Processing Record 29 of Set 15 | isabela
# Processing Record 30 of Set 15 | agadir
# Processing Record 31 of Set 15 | caconda
# Processing Record 32 of Set 15 | rondonopolis
# Processing Record 33 of Set 15 | kormilovka
# Processing Record 34 of Set 15 | praia da vitoria
# Processing Record 35 of Set 15 | temiscaming
# Processing Record 36 of Set 15 | la sarre
# Processing Record 37 of Set 15 | svetlogorsk
# Processing Record 38 of Set 15 | gari
# Processing Record 39 of Set 15 | nkoteng
# Processing Record 40 of Set 15 | kirkwall
# Processing Record 41 of Set 15 | lucapa
# Processing Record 42 of Set 15 | koutsouras
# Processing Record 43 of Set 15 | wlodawa
# Processing Record 44 of Set 15 | bay roberts
# Processing Record 45 of Set 15 | ludvika
# Processing Record 46 of Set 15 | arshan
# Processing Record 47 of Set 15 | corning
# Processing Record 48 of Set 15 | polunochnoye
# Processing Record 49 of Set 15 | heubach
# Processing Record 50 of Set 15 | romitan
# Processing Record 1 of Set 16 | kalmunai
# Processing Record 2 of Set 16 | odweyne
# Processing Record 3 of Set 16 | trelew
# Processing Record 4 of Set 16 | zelenoborsk
# Processing Record 5 of Set 16 | yarada
# Processing Record 6 of Set 16 | anifion
# City not found. Skipping...
# Processing Record 7 of Set 16 | dudinka
# Processing Record 8 of Set 16 | posse
# Processing Record 9 of Set 16 | haftoni
# Processing Record 10 of Set 16 | jamame
# Processing Record 11 of Set 16 | kharp
# Processing Record 12 of Set 16 | acarau
# Processing Record 13 of Set 16 | iquitos
# Processing Record 14 of Set 16 | moryakovskiy zaton
# Processing Record 15 of Set 16 | mihaileni
# Processing Record 16 of Set 16 | joensuu
# Processing Record 17 of Set 16 | jaragua
# Processing Record 18 of Set 16 | kindu
# Processing Record 19 of Set 16 | ourossogui
# Processing Record 20 of Set 16 | duiwelskloof
# Processing Record 21 of Set 16 | le pradet
# Processing Record 22 of Set 16 | barra
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Length of our array (> 500 would be good)
len(city_data)
# Out:
# 723

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Mar Del Plata -38.0023  -57.5575     70.88        88           0
# 1     Georgetown   5.4112  100.3354     79.90        86          73
# 2         Gwadar  25.1216   62.3254     74.46        78           0
# 3       Oksfjord  70.2396   22.3479     30.00        97         100
# 4    Montecristo   8.2971  -74.4733     84.97        71          84
# 5   Campos Novos -27.4017  -51.2250     79.90        46          32
# 6      Bonavista  48.6499  -53.1147     30.11        71          26
# 7       Hermanus -34.4187   19.2345     73.90        75          50
# 8          Lucea  18.4510  -78.1736     82.85        69         100
# 9     Oranjemund -28.5500   16.4333     67.23        69           0
#
#    Wind Speed Country Current Description                 Date
# 0       10.00      AR           clear sky  2021-12-22 17:06:40
# 1        4.56      MY       broken clouds  2021-12-22 17:06:27
# 2       13.29      PK           clear sky  2021-12-22 17:06:41
# 3       17.13      NO          light snow  2021-12-22 17:06:41
# 4        3.76      CO       broken clouds  2021-12-22 17:06:41
# 5        6.60      BR    scattered clouds  2021-12-22 17:06:42
# 6       15.95      CA    scattered clouds  2021-12-22 17:06:42
# 7       20.02      ZA    scattered clouds  2021-12-22 17:06:42
# 8        5.14      JM     overcast clouds  2021-12-22 17:06:43
# 9        7.65      NA           clear sky  2021-12-22 17:06:43

# %%
# Reorder the columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Mar Del Plata      AR -38.0023  -57.5575     70.88        88           0
# 1     Georgetown      MY   5.4112  100.3354     79.90        86          73
# 2         Gwadar      PK  25.1216   62.3254     74.46        78           0
# 3       Oksfjord      NO  70.2396   22.3479     30.00        97         100
# 4    Montecristo      CO   8.2971  -74.4733     84.97        71          84
#
#    Wind Speed Current Description
# 0       10.00           clear sky
# 1        4.56       broken clouds
# 2       13.29           clear sky
# 3       17.13          light snow
# 4        3.76       broken clouds

# %%
# Create the output file (CSV)
output_data_file = "Weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
